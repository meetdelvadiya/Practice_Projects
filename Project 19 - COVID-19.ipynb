# %%
import numpy as np
import pandas as pd
from pandas import datetime
from pandas import read_csv
from pandas import DataFrame
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
from statsmodels.tsa.arima_model import ARIMA

import warnings 
from scipy import stats
from scipy.stats import norm
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('aggregate_covid_country.csv')
df.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-22      Albania          0          0       0
# 2  2020-01-22      Algeria          0          0       0
# 3  2020-01-22      Andorra          0          0       0
# 4  2020-01-22       Angola          0          0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23688 non-null  object
#  1   Country    23688 non-null  object
#  2   Confirmed  23688 non-null  int64
#  3   Recovered  23688 non-null  int64
#  4   Deaths     23688 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 925.4+ KB

# %%
df.shape
# Out:
# (23688, 5)

# %%
df.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
df.describe()
# Out:
#           Confirmed      Recovered        Deaths
# count  2.368800e+04   23688.000000  23688.000000
# mean   7.969368e+03    2581.801714    526.935030
# std    5.842109e+04   15143.101257   3992.815956
# min    0.000000e+00       0.000000      0.000000
# 25%    0.000000e+00       0.000000      0.000000
# 50%    1.800000e+01       1.000000      0.000000
# 75%    7.300000e+02     123.000000     13.000000
# max    1.680913e+06  384902.000000  98913.000000

# %%
df.skew()
# Out:
# Confirmed    18.674502
# Recovered    10.662286
# Deaths       14.218167
# dtype: float64

# %%
df['Total Active'] = df['Confirmed']
total_active = df['Total Active'].sum()
Total_Cases = df.groupby('Country')['Total Active'].sum().sort_values(ascending=False).to_frame()
Total_Cases.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_e0187be2_6644_11eb_a51a_3417eb5e35earow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e0187be2_6644_11eb_a51a_3417eb5e35earow1_col0 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_e0187be2_6644_11eb_a51a_3417eb5e35earow2_col0 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_e0187be2_6644_11eb_a51a_3417eb5e35earow3_col0 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_e0187be2_6644_11eb_a51a_3417eb5e35earow4_col0 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_e0187be2_6644_11eb_a51a_3417eb5e35earow5_col0 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_e0187be2_6644_11eb_a51a_3417eb5e35earow6_col0 {
#             background-color:  #fed8c7;
#             color:  #000000;
# ...

# %%
plt.figure(figsize=(20,10))
x = df['Date']
y = df['Deaths']
plt.plot(x,y)

# %% [markdown]
# Thus, we can see that Number of Death increases exponentially with respect to time
